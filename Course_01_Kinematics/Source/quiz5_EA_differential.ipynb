# %% [markdown]
# <a href="https://colab.research.google.com/github/seoupark1/Spacecraft-Dynamics-and-Control/blob/main/Course_01_Kinematics/Source/quiz5_EA_differential.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# ## 📝 Quiz 5 - Problem 1
# ![Problem 1](https://github.com/seoupark1/Spacecraft-Dynamics-and-Control/blob/main/Course_01_Kinematics/note/quiz5_prob1.png?raw=true)

# %%
# matlab 대신 octave 사용

# !apt-get update > /dev/null 2>&1
# !apt-get install octave > /dev/null 2>&1
# !pip install oct2py

# %load_ext oct2py.ipython

# %%
# %%octave
# 1;
#
# function dydt = func(t, y)
#     C = [0, sin(y(3)), cos(y(3));
#         0, cos(y(3))*cos(y(2)), -sin(y(3))*cos(y(2));
#         cos(y(2)), sin(y(3))*sin(y(2)), cos(y(3))*sin(y(2))] / cos(y(2));
#     omega = 20 * [sin(0.1*t);
#             0.01;
#             cos(0.1*t)] * (pi/180);
#     dydt = C * omega;
#
# end
#
# % Euler angles at 60s
# tspan = [0, 42, 60];
# y0 = [40; 30; 80] * (pi/180);
# [t, y] = ode45(@func, tspan, y0);
# disp([t(end), y(end, 1), y(end, 2), y(end, 3)]);
#
# % Euler angles at 42s
# psi = y(2, 1);
# theta = y(2, 2);
# phi = y(2, 3);
# norm = sqrt(psi^2 + theta^2 + phi^2);
# disp(norm);
# Out:
#    60.0000    3.5432   -0.4557   -0.6618
# 6.1566
