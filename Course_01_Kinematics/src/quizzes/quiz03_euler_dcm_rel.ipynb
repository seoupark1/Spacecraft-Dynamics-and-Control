# %% [markdown]
# <a href="https://colab.research.google.com/github/seoupark1/Spacecraft-Dynamics-and-Control/blob/main/Course_01_Kinematics/src/quizzes/quiz03_euler_dcm_rel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 📝 Quiz 03 - Problem 1
# ![Problem 1](https://github.com/seoupark1/Spacecraft-Dynamics-and-Control/blob/main/assets/images/course01/quiz03_prob1.png?raw=true)

# %%
# 3-1-3 DCM으로부터 EA 구하는 공식에 같은 위치의 3-2-1 DCM 성분을 대입

import math

def result():
    theta1 = math.radians(20)
    theta2 = math.radians(10)
    theta3 = math.radians(-10)

    c_31 = math.cos(theta3)*math.sin(theta2)*math.cos(theta1) + math.sin(theta3)*math.sin(theta1)
    c_32 = math.cos(theta3)*math.sin(theta2)*math.sin(theta1) - math.sin(theta3)*math.cos(theta1)
    c_33 = math.cos(theta3)*math.cos(theta2)
    c_13 = -math.sin(theta2)
    c_23 = math.sin(theta3)*math.cos(theta2)

    theta1 = math.atan2(c_31, -c_32) # 역탄젠트 함수 사분면 주의
    theta2 = math.acos(c_33)
    theta3 = math.atan2(c_13, c_23)

    eulerAngles = [theta1, theta2, theta3] # radians
    return eulerAngles

print(result())
# Out:
# [2.712914457359832, 0.24619691677893243, -2.348540373423724]
