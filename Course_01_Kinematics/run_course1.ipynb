# %%
# 1. 깃허브 저장소를 코랩 서버로 가져옵니다.
# !git clone https://github.com/seoupark1/Spacecraft-Dynamics-and-Control.git
# %cd Spacecraft-Dynamics-and-Control/Course_01_Kinematics/Source/
print('🚀 1단원 퀴즈 환경 구축 완료!')

# %%
# %% [markdown]
# ## 📝 Quiz 1: Direction Cosine Matrix (DCM) 변환

# 1) 교수님이 코드를 보실 수 있게 화면에 소스코드를 먼저 출력합니다.
with open('quiz1_DCM.py', 'r', encoding='utf-8') as f:
    print(f.read())

print('\n' + '='*50 + '\n[실행 결과]\n' + '='*50)

# 2) 이어서 코드를 실제로 실행합니다.
# %run quiz1_DCM.py

# %%
# %% [markdown]
# ## 📝 Quiz 2: Quaternion Kinematics

with open('quiz2.py', 'r', encoding='utf-8') as f:
    print(f.read())

print('\n' + '='*50 + '\n[실행 결과]\n' + '='*50)

# %run quiz2.py
