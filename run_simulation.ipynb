# %%
# 1. 내 GitHub 저장소 통째로 웹 서버에 불러오기
# !git clone https://github.com/seoupark1/Spacecraft-dynamics-and-control.git

# 2. 불러온 폴더 안으로 이동하기
# %cd 저장소이름

# 3. 웹 상에서 내 .py 파일 직접 실행하기
# !python spacecraft_kinematics.py
